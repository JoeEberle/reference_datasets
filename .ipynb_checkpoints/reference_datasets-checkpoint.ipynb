# %% [markdown]
# ![datasets.png](attachment:datasets.png)

# %% [markdown]
# # Exploratory Data Analysis of Multiple Data Sets

# %% [markdown]
# ## Required Setup Step 0 - Install and Import all necessary Libraries

# %%
first_install = False
if first_install:
    # !pip install ydata-profiling
    # !pip install seaborn
    # !pip install matplotlib    
    # !pip install pyttsx3

# %%
# Import Libraries for Spreadsheet Automation 
import pandas as pd
import datetime as dt
from datetime import date
import os, glob, time
from platform import python_version
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Read in the Data Set

# %%
# df_penguins = sns.load_dataset("penguins")

# %% [markdown]
# # Read in the Data Set - From MY GitHub

# %%
getting_penguin_data = True
if getting_penguin_data: 
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/penguins.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_penguins = df

# %%
getting_mushroom_data = False
if getting_mushroom_data: 
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/mushrooms.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_mushrooms = df

# %%
getting_admission_prediction_data = False
if getting_admission_prediction_data: 
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/Admission_Predict.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_admission_prediction = df

# %%
getting_world_happiness_data = False
if getting_world_happiness_data: 
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/world_happiness_2015.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_world_happiness_2015 = df

# %%
getting_titanic_data = True
if getting_titanic_data: 
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/titanic.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_titanic = df

# %%
getting_diabetes_data = False
if getting_diabetes_data: 
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/diabetes.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_diabetes = df

# %%
getting_heart_data = False
if getting_heart_data: 
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/heart.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_heart = df

# %%
kidney_data = False
if kidney_data: 
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/kidney_disease.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_diabetes = df

# %%
getting_world_happiness_data = False
if getting_world_happiness_data: 
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/world_happiness_2016.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_world_happiness_2016 = df    
    
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/world_happiness_2017.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_world_happiness_2017 = df      
    
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/world_happiness_2018.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_world_happiness_2018 = df       
    
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/world_happiness_2019.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_world_happiness_2019 = df  
    
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/world_happiness_2020.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_world_happiness_2020 = df     
    
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/world_happiness_2021.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_world_happiness_2021 = df   
    
    df = pd.read_csv("https://raw.githubusercontent.com/JoeEberle/datasets/main/world_happiness_2022.csv")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns')
    df_world_happiness_2022 = df

# %%
df_penguins.head()

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ## Drop any incomplete data rows

# %%
df_penguins = df_penguins.dropna()

# %% [markdown]
# ## How Big is the Data ???

# %%
print(f"The number of rows in this data is {df_penguins.shape[0]} and Number of columns {df_penguins.shape[1]} ")

# %%
print(df_penguins.info())
df_penguins.columns

# %% [markdown]
# # How many data rows of each  species?

# %%
df_penguins['species'].value_counts()

# %%
df_penguins['species'].value_counts().plot(kind='bar', color=['r','g','b'], title = 'How any of each  species?')

# %% [markdown]
# # How many islands are in the data set ?

# %%
df_penguins['island'].value_counts().plot(kind='bar', color=['r','g','b'], title = 'How many row of each island?')

# %% [markdown]
# # What is the body mass (grams) of each species?

# %%
df_penguins['island'].value_counts().plot(kind='bar',  color=['r','g','b'], title = 'How many of each  species?')

# %% [markdown]
# # How many Penguins of each gender ?

# %%
df_penguins['sex'].value_counts().plot(kind='pie', autopct='%.2f', figsize=[4,4], title = 'How many of each  species?')

# %% [markdown]
# # What is the body mass (grams) of each species?

# %%
sns.barplot(x='body_mass_g', y='species',  data = df_penguins);

# %% [markdown]
# # Display Correlation Between 2 Independent Features

# %%
sns.relplot(data=df_penguins, x='bill_length_mm', y='body_mass_g',  hue='species')

# %%
sns.relplot(data=df_penguins, x='bill_depth_mm', y='body_mass_g',  hue='species')

# %%
sns.relplot(data=df_penguins, x='flipper_length_mm', y='body_mass_g', hue='species')

# %%
sns.relplot(data=df_penguins, x='flipper_length_mm', y='body_mass_g', hue='sex')

# %% [markdown]
# # Display Correlation Between ALL Independent Features by SPECIES

# %%
sns.pairplot(data=df_penguins, hue='species')

# %%
import plotly.express as px

fig = px.scatter_3d(df_penguins, x='bill_length_mm', y='flipper_length_mm', z='body_mass_g',
                    color='species', symbol='species')

# Update the layout to make the plot larger
fig.update_layout(width=1000, height=800)  # Adjust the width and height as needed


fig.show()

# %% [markdown]
# # Optional Display a Correlation Heatmap

# %%
def display_Correlation_heatmap(df):
    correlation_matrix = df.corr(numeric_only=True)     #establish a correlation matrix for all fields
    top_correlation_features = correlation_matrix.index
    plt.figure(figsize=(8,8))
    g=sns.heatmap(df[top_correlation_features].corr(),annot=True,cmap="RdYlGn")
    
    
creating_correlation_heatmap = True
if creating_correlation_heatmap:
    display_Correlation_heatmap(df_penguins)

# %% [markdown]
# # Display Correlation Between ALL Independent Features

# %%
sns.pairplot(data=df_penguins, hue='island')

# %% [markdown]
# # Adding Value Count Labels to Bars

# %%
import matplotlib.pyplot as plt

# Get value counts for the 'species' column
species_counts = df_penguins['species'].value_counts()
# Create a bar plot
ax = species_counts.plot(kind='bar', color=['r', 'g', 'b'], title='How many of each species?')
# Add value counts as text labels on top of the bars
for i, count in enumerate(species_counts):
    ax.text(i, count + 0.2, str(count), ha='center', va='bottom', fontsize=10)
# Show the plot
plt.show()

# %% [markdown]
# # One hot encoding  using PANDAS - DONT DO THIS !!!!

# %%
# Select columns to one-hot encode
columns_to_encode = ['species', 'island', 'sex']

# Perform one-hot encoding
df_penquins_one_hot = pd.get_dummies(df_penguins, columns=columns_to_encode)

# Display the encoded DataFrame
df_penquins_one_hot.head()

# %% [markdown]
# # One hot encoding  using SCI-KIT Learn - DO THIS INSTEAD !!!!

# %%
from sklearn.preprocessing import LabelEncoder

df = df_penguins

# Assuming df is your DataFrame
columns_to_encode = ['species', 'island', 'sex']

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to selected columns
for column in columns_to_encode:
    df[column] = label_encoder.fit_transform(df[column])

# Display the updated DataFrame
df_penquins_one_hot = df
df_penquins_one_hot.head()

# %%
import plotly.express as px

fig = px.scatter_3d(df_penguins, x='bill_length_mm', y='flipper_length_mm', z='body_mass_g',
                    color='species', symbol='species')

# Update the layout to make the plot larger
fig.update_layout(width=1000, height=800)  # Adjust the width and height as needed


fig.show()
